# %%
# !pip install -q librosa scipy pandas openpyxl gdown matplotlib
# !pip install -q transformers
# !pip install -q torch torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install pytorch-tcn
# Out:
# Collecting pytorch-tcn
#   Downloading pytorch_tcn-1.2.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from pytorch-tcn) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch-tcn) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tcn) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->pytorch-tcn) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pytorch-tcn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->pytorch-tcn) (3.0.3)
# Downloading pytorch_tcn-1.2.3-py3-none-any.whl (18 kB)
# Installing collected packages: pytorch-tcn
# Successfully installed pytorch-tcn-1.2.3

# %%
# !git clone https://github.com/MarijaGijic/AI-SPEAK_catB.git
# Out:
# Cloning into 'AI-SPEAK_catB'...
# remote: Enumerating objects: 255, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 255 (delta 67), reused 82 (delta 56), pack-reused 155 (from 1)
# Receiving objects: 100% (255/255), 3.89 MiB | 5.89 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
# %cd AI-SPEAK_catB
# Out:
# /content/AI-SPEAK_catB

# %%
# !python download_data.py
# Out:
# Downloading spk14_blendshapes.zip
# Downloading...
# From (original): https://drive.google.com/uc?id=1AqENkQjMEC4BLUVaaXIueK4q-KwQyD7S
# From (redirected): https://drive.google.com/uc?id=1AqENkQjMEC4BLUVaaXIueK4q-KwQyD7S&confirm=t&uuid=f73b3d4a-1f77-4412-be40-0cf00921eac3
# To: /content/AI-SPEAK_catB/data/spk14_blendshapes.zip
# 100% 59.4M/59.4M [00:01<00:00, 39.9MB/s]
# Unzipping spk14_blendshapes.zip
# Downloading spk08_blendshapes.zip
# Downloading...
# From (original): https://drive.google.com/uc?id=1onjc_aw990qQAsvszLSI9rpXS2SkJFVd
# From (redirected): https://drive.google.com/uc?id=1onjc_aw990qQAsvszLSI9rpXS2SkJFVd&confirm=t&uuid=7dbd96bc-ccc1-488a-a39d-40dcd30ac527
# To: /content/AI-SPEAK_catB/data/spk08_blendshapes.zip
# 100% 67.9M/67.9M [00:01<00:00, 36.4MB/s]
# Unzipping spk08_blendshapes.zip
# Downloading labels_aligned.zip
# Downloading...
# From: https://drive.google.com/uc?id=1KduEMO5DqqdQLXPd45W6knSFIuODxMqR
# To: /content/AI-SPEAK_catB/data/labels_aligned.zip
# 100% 278k/278k [00:00<00:00, 3.56MB/s]
# Unzipping labels_aligned.zip
# Downloading audio_synth.zip
# Downloading...
# From (original): https://drive.google.com/uc?id=16e8VnAhH2L-smgt9FGpwC1k0bhA8X6Kq
# From (redirected): https://drive.google.com/uc?id=16e8VnAhH2L-smgt9FGpwC1k0bhA8X6Kq&confirm=t&uuid=705be5e5-b6b5-48e0-912f-e0b19986aa99
# To: /content/AI-SPEAK_catB/data/audio_synth.zip
# 100% 38.7M/38.7M [00:01<00:00, 35.1MB/s]
# Unzipping audio_synth.zip
# Downloading test_set_catB.zip
# Downloading...
# From: https://drive.google.com/uc?id=1dbQTuS9Kw5-1iiqfAt0jQUqlJEUBFCyx
# To: /content/AI-SPEAK_catB/data/test_set_catB.zip
# 100% 4.01M/4.01M [00:00<00:00, 23.9MB/s]
# Unzipping test_set_catB.zip
# Download and unzip finished!
#
# Folder structure:
# data/
#   spk08_blendshapes/
#     renamed_spk08/  [356 files]
#   test_set_catB/
#     test_set_catB/  [13 files]
#   audio_synth/
#     synth/  [353 files]
#   spk14_blendshapes/
#     renamed_spk14/  [360 files]
#   labels_aligned/
#     labels_aligned/
#       per_phoneme/  [358 files]
#       per_word/  [358 files]

# %%
from src.utils.dataset import BlendshapeDataset, collate_fn_mfcc, collate_fn_hubert
from src.config import BLENDSHAPE_NAMES
from torch.utils.data import DataLoader

DATA_ROOT = 'data'
ds = BlendshapeDataset(DATA_ROOT, speakers=['spk08', 'spk14'], load_synth=False, use_preprocessing=True, hubert_dir=None)
# Out:
# [Dataset] 358 real + 0 synth = 358 total samples

# %%
from genericpath import exists
result_dict = "/content/results_final"
import os
os.mkdir(result_dict)

# %%
import os, time, json
import numpy as np
import pandas as pd
import soundfile as sf
import torch
from scipy.signal import savgol_filter

from src.preprocessing.audio import preprocess_waveform, resample_for_hubert
from src.preprocessing.features import extract_audio_features
from src.models.tcn import BlendshapeTCN


TEST_DIR   = "/content/AI-SPEAK_catB/data/test_set_catB/test_set_catB"
CKPT_PATH  = "/content/best_model_tcn_mfcc.pt"
SUBMIT_DIR = "submission_final"
FPS        = 60

os.makedirs(SUBMIT_DIR, exist_ok=True)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")


ckpt   = torch.load(CKPT_PATH, map_location=device)
config = ckpt.get("config", {})

model = BlendshapeTCN(
    audio_type   = "mfcc",
    d_model      = config.get("d_model", 256),
    use_phonemes = config.get("use_phonemes", True),
    n_layers     = config.get("n_layers", 5),
).to(device)
model.load_state_dict(ckpt["model_state"])
model.eval()
print(f"Model učitan — epoha {ckpt.get('epoch','?')}  val_loss={ckpt.get('val_loss', float('nan')):.5f}")

test_wavs = sorted([
    os.path.join(TEST_DIR, f)
    for f in os.listdir(TEST_DIR)
    if f.lower().endswith(".wav")
])
print(f"Pronađeno {len(test_wavs)} fajlova.")

all_meta = {}

for wav_path in test_wavs:
    base_name = os.path.splitext(os.path.basename(wav_path))[0]
    out_name  = f"{base_name}_result"
    print(f"\n{'='*55}")
    print(f"Obrada: {base_name}.wav")


    audio_duration_sec = sf.info(wav_path).duration

    t0 = time.perf_counter()

    audio    = preprocess_waveform(wav_path)   # mono + normalizacija
    n_frames = int(audio_duration_sec * FPS)

    af = extract_audio_features(wav_path, n_frames, use_preprocessing=True)
    af_t = torch.from_numpy(af).unsqueeze(0).to(device)   # (1, T, D_mfcc)

    pi = torch.zeros((1, n_frames),      dtype=torch.long,    device=device)
    pt = torch.zeros((1, n_frames, 1),   dtype=torch.float32, device=device)
    si = torch.zeros((1, n_frames),      dtype=torch.long,    device=device)
    ln = torch.tensor([n_frames],        dtype=torch.long,    device=device)

    with torch.no_grad():
        pred = model(
            af=af_t, pi=pi, pt=pt, si=si, lengths=ln
        ).squeeze(0).cpu().numpy()   # (T, 52)

    inference_time_sec = time.perf_counter() - t0

    pred_smooth = savgol_filter(pred, window_length=7, polyorder=2, axis=0)
    pred_smooth = np.clip(pred_smooth, 0.0, 1.0).astype(np.float32)


    rtf          = inference_time_sec / audio_duration_sec
    lookahead_ms = 0

    print(f"  Trajanje:           {audio_duration_sec:.3f} s")
    print(f"  Frejmovi:           {n_frames}")
    print(f"  inference_time_sec: {inference_time_sec:.4f} s")
    print(f"  RTF:                {rtf:.4f}  ({'✓ real-time' if rtf < 1 else '✗ sporije'})")
    print(f"  lookahead_ms:       {lookahead_ms:.1f} ms")


    csv_path = os.path.join(SUBMIT_DIR, f"{out_name}.csv")
    pd.DataFrame(pred_smooth).to_csv(
        csv_path, index=False, header=False, float_format="%.6f"
    )
    print(f"  → {csv_path}")

    all_meta[out_name] = {
        "inference_time_sec": round(inference_time_sec, 4),
        "audio_duration_sec": round(audio_duration_sec, 4),
        "rtf":                round(rtf, 6),
        "lookahead_ms":       round(lookahead_ms, 1),
        "fps_out":            FPS,
        "n_frames":           int(pred_smooth.shape[0]),
    }


meta_path = os.path.join(SUBMIT_DIR, "meta.json")
with open(meta_path, "w") as f:
    json.dump(all_meta, f, indent=2)

print(f"\n{'='*55}")
print(f"{'Fajl':<30} {'inf(s)':>8} {'RTF':>8}")
print("-" * 55)
for name, m in all_meta.items():
    flag = "✓" if m["rtf"] < 1 else "✗"
    print(f"{name:<30} {m['inference_time_sec']:>8.4f} {m['rtf']:>7.4f}{flag}")
print(f"\nSačuvano u: {os.path.abspath(SUBMIT_DIR)}")
print(json.dumps(all_meta, indent=2))
# Out:
# Device: cuda
# TCN: 5 slojeva, RF=125 frejmova (2083ms)
# Parametara: 3,145,764
# Model učitan — epoha 80  val_loss=0.00544
# Pronađeno 12 fajlova.
#
# =======================================================
# Obrada: Jovana1.wav
#   Trajanje:           4.490 s
#   Frejmovi:           269
#   inference_time_sec: 0.1058 s
#   RTF:                0.0236  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Jovana1_result.csv
#
# =======================================================
# Obrada: Jovana5.wav
#   Trajanje:           3.715 s
#   Frejmovi:           222
#   inference_time_sec: 0.1658 s
#   RTF:                0.0446  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Jovana5_result.csv
#
# =======================================================
# Obrada: Sinisa1.wav
#   Trajanje:           5.234 s
#   Frejmovi:           314
#   inference_time_sec: 0.3499 s
#   RTF:                0.0669  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Sinisa1_result.csv
#
# =======================================================
# Obrada: Sinisa7.wav
#   Trajanje:           4.424 s
#   Frejmovi:           265
#   inference_time_sec: 0.1610 s
#   RTF:                0.0364  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Sinisa7_result.csv
#
# =======================================================
# Obrada: Stefan1.wav
#   Trajanje:           4.510 s
#   Frejmovi:           270
#   inference_time_sec: 0.2813 s
#   RTF:                0.0624  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Stefan1_result.csv
#
# =======================================================
# Obrada: Stefan2.wav
#   Trajanje:           4.130 s
#   Frejmovi:           247
#   inference_time_sec: 0.3097 s
#   RTF:                0.0750  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Stefan2_result.csv
#
# =======================================================
# Obrada: Stefan4.wav
#   Trajanje:           3.760 s
#   Frejmovi:           225
#   inference_time_sec: 0.2519 s
#   RTF:                0.0670  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Stefan4_result.csv
#
# =======================================================
# Obrada: Stefan6.wav
#   Trajanje:           4.125 s
#   Frejmovi:           247
#   inference_time_sec: 0.1129 s
#   RTF:                0.0274  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Stefan6_result.csv
#
# =======================================================
# Obrada: Stefan9.wav
#   Trajanje:           4.125 s
#   Frejmovi:           247
#   inference_time_sec: 0.1464 s
#   RTF:                0.0355  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Stefan9_result.csv
#
# =======================================================
# Obrada: Tijana1.wav
#   Trajanje:           5.907 s
#   Frejmovi:           354
#   inference_time_sec: 0.2683 s
#   RTF:                0.0454  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Tijana1_result.csv
#
# =======================================================
# Obrada: Tijana10.wav
#   Trajanje:           3.943 s
#   Frejmovi:           236
#   inference_time_sec: 0.3723 s
#   RTF:                0.0944  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Tijana10_result.csv
#
# =======================================================
# Obrada: Tijana8.wav
#   Trajanje:           4.762 s
#   Frejmovi:           285
#   inference_time_sec: 0.5258 s
#   RTF:                0.1104  (✓ real-time)
#   lookahead_ms:       0.0 ms
#   → submission_final/Tijana8_result.csv
#
# =======================================================
# Fajl                             inf(s)      RTF
# -------------------------------------------------------
# Jovana1_result                   0.1058  0.0236✓
# Jovana5_result                   0.1658  0.0446✓
# Sinisa1_result                   0.3499  0.0669✓
# Sinisa7_result                   0.1610  0.0364✓
# Stefan1_result                   0.2813  0.0624✓
# Stefan2_result                   0.3097  0.0750✓
# Stefan4_result                   0.2519  0.0670✓
# Stefan6_result                   0.1129  0.0274✓
# Stefan9_result                   0.1464  0.0355✓
# Tijana1_result                   0.2683  0.0454✓
# Tijana10_result                  0.3723  0.0944✓
# Tijana8_result                   0.5258  0.1104✓
#
# Sačuvano u: /content/AI-SPEAK_catB/submission_final
# {
#   "Jovana1_result": {
#     "inference_time_sec": 0.1058,
#     "audio_duration_sec": 4.49,
#     "rtf": 0.023559,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 269
#   },
#   "Jovana5_result": {
#     "inference_time_sec": 0.1658,
#     "audio_duration_sec": 3.715,
#     "rtf": 0.044624,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 222
#   },
#   "Sinisa1_result": {
#     "inference_time_sec": 0.3499,
#     "audio_duration_sec": 5.2336,
#     "rtf": 0.066855,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 314
#   },
#   "Sinisa7_result": {
#     "inference_time_sec": 0.161,
#     "audio_duration_sec": 4.4244,
#     "rtf": 0.03639,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 265
#   },
#   "Stefan1_result": {
#     "inference_time_sec": 0.2813,
#     "audio_duration_sec": 4.51,
#     "rtf": 0.062365,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 270
#   },
#   "Stefan2_result": {
#     "inference_time_sec": 0.3097,
#     "audio_duration_sec": 4.13,
#     "rtf": 0.074982,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 247
#   },
#   "Stefan4_result": {
#     "inference_time_sec": 0.2519,
#     "audio_duration_sec": 3.76,
#     "rtf": 0.067003,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 225
#   },
#   "Stefan6_result": {
#     "inference_time_sec": 0.1129,
#     "audio_duration_sec": 4.125,
#     "rtf": 0.027374,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 247
#   },
#   "Stefan9_result": {
#     "inference_time_sec": 0.1464,
#     "audio_duration_sec": 4.125,
#     "rtf": 0.035489,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 247
#   },
#   "Tijana1_result": {
#     "inference_time_sec": 0.2683,
#     "audio_duration_sec": 5.9073,
#     "rtf": 0.045423,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 354
#   },
#   "Tijana10_result": {
#     "inference_time_sec": 0.3723,
#     "audio_duration_sec": 3.9431,
#     "rtf": 0.094407,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 236
#   },
#   "Tijana8_result": {
#     "inference_time_sec": 0.5258,
#     "audio_duration_sec": 4.7617,
#     "rtf": 0.110419,
#     "lookahead_ms": 0,
#     "fps_out": 60,
#     "n_frames": 285
#   }
# }
